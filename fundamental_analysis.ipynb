# %%
pip install yfinance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
symbol = 'GOOGL'
stock = yf.Ticker(symbol)

# %%
stock.info
# Out:
# {'zip': '94043',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 150028,
#  'longBusinessSummary': 'Larry Page and Sergey Brin founded Google in September 1998. Since then, the company has grown to more than 130,000 employees worldwide, with a wide range of popular products and platforms like Search, Maps, Ads, Gmail, Android, Chrome, Google Cloud and YouTube. In October 2015, Alphabet became the parent holding company of Google.',
#  'city': 'Mountain View',
#  'phone': '650 253 0000',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.abc.xyz',
#  'maxAge': 1,
#  'address1': '1600 Amphitheatre Parkway',
#  'industry': 'Internet Content & Information',
#  'ebitdaMargins': 0.35616,
#  'profitMargins': 0.29521,
#  'grossMargins': 0.56511,
#  'operatingCashflow': 89395003392,
#  'revenueGrowth': 0.41,
#  'operatingMargins': 0.303,
#  'ebitda': 85196996608,
#  'targetLowPrice': 1850,
#  'recommendationKey': 'buy',
#  'grossProfits': 97795000000,
#  'freeCashflow': 52658749440,
#  'targetMedianPrice': 3350,
#  'currentPrice': 2740.34,
#  'earningsGrowth': 0.707,
#  'currentRatio': 2.98,
#  'returnOnAssets': 0.14011,
#  'numberOfAnalystOpinions': 44,
#  'targetMeanPrice': 3301.2,
#  'debtToEquity': 11.493,
#  'returnOnEquity': 0.30872,
#  'targetHighPrice': 3925,
#  'totalCash': 142002995200,
#  'totalDebt': 28109000704,
#  'totalRevenue': 239210004480,
#  'totalCashPerShare': 213.936,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 356.562,
#  'quickRatio': 2.862,
#  'recommendationMean': 1.7,
#  'exchange': 'NMS',
#  'shortName': 'Alphabet Inc.',
#  'longName': 'Alphabet Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'GOOGL',
#  'messageBoardId': 'finmb_29096',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 7.128,
#  'beta3Year': None,
#  'enterpriseToEbitda': 20.013,
#  '52WeekChange': 0.56030035,
#  'morningStarRiskRating': None,
#  'forwardEps': 112.42,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 300809984,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 367.946,
#  'sharesShort': 2061501,
#  'sharesPercentSharesOut': 0.0031,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.79738,
#  'netIncomeToCommon': 70617997312,
#  'trailingEps': 103.805,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.23092365,
#  'priceToBook': 7.447669,
#  'heldPercentInsiders': 0.0015,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1632960000,
#  'shortRatio': 1.39,
#  'sharesShortPreviousMonthDate': 1636934400,
#  'floatShares': 578403944,
#  'beta': 1.058286,
#  'enterpriseValue': 1705045000192,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1396483200,
#  'lastSplitFactor': '1998:1000',
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.684,
#  'priceToSalesTrailing12Months': 7.60361,
#  'dateShortInterest': 1639526400,
#  'pegRatio': 1.27,
#  'ytdReturn': None,
#  'forwardPE': 24.375914,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0069,
#  'sharesShortPriorMonth': 2555428,
#  'impliedSharesOutstanding': 663763968,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 2754.95,
#  'regularMarketOpen': 2762.91,
#  'twoHundredDayAverage': 2639.538,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 2768.9,
#  'navPrice': None,
#  'averageDailyVolume10Day': 1322710,
#  'regularMarketPreviousClose': 2754.95,
#  'fiftyDayAverage': 2908.4165,
#  'trailingAnnualDividendRate': None,
#  'open': 2762.91,
#  'toCurrency': None,
#  'averageVolume10days': 1322710,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 2715.81,
#  'currency': 'USD',
#  'trailingPE': 26.398922,
#  'regularMarketVolume': 1488028,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1818859536384,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 1533752,
#  'dayLow': 2715.81,
#  'ask': 2741.39,
#  'askSize': 900,
#  'volume': 1488028,
#  'fiftyTwoWeekHigh': 3019.33,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow':
000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        27193000000.0   34913000000.0
# Minority Interest                                 None            None
# Net Income                               12662000000.0   30736000000.0
# Selling General Administrative           19733000000.0   23256000000.0
# Gross Profit                             65272000000.0   77270000000.0
# Ebit                                     28914000000.0   32595000000.0
# Operating Income                         28914000000.0   32595000000.0
# Other Operating Expenses                          None            None
# Interest Expense                          -109000000.0    -114000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                       14531000000.0    4177000000.0
# Total Revenue                           110855000000.0  136819000000.0
# Total Operating Expenses                 81941000000.0  104224000000.0
# Cost Of Revenue                          45583000000.0   59549000000.0
# Total Other Income Expense Net           -1721000000.0    2318000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           12662000000.0   30736000000.0
# Net Income Applicable To Common Shares   12662000000.0   30736000000.0
#
#                                             2019-12-31      2020-12-31
# Research Development                     26018000000.0   27573000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        39625000000.0   48082000000.0
# Minority Interest                                 None            None
# Net Income                               34343000000.0   40269000000.0
# Selling General Administrative           27461000000.0   28998000000.0
# Gross Profit                             89961000000.0   97795000000.0
# Ebit                                     36482000000.0   41224000000.0
# Operating Income                         36482000000.0   41224000000.0
# Other Operating Expenses                          None            None
# Interest Expense                          -100000000.0    -135000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                        5282000000.0    7813000000.0
# Total Revenue                           161857000000.0  182527000000.0
# Total Operating Expenses                125375000000.0  141303000000.0
# Cost Of Revenue                          71896000000.0   84732000000.0
# Total Other Income Expense Net            3143000000.0    6858000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           34343000000.0   40269000000.0
# Net Income Applicable To Common Shares   34343000000.0   40269000000.0

# %%
IC.loc['Net Income Applicable To Common Shares']
# Out:
# 2017-12-31    12662000000.0
# 2018-12-31    30736000000.0
# 2019-12-31    34343000000.0
# 2020-12-31    40269000000.0
# Name: Net Income Applicable To Common Shares, dtype: object

# %%
NI = IC.loc['Net Income Applicable To Common Shares'].astype(float)

# %%
plt.plot(NI)
plt.xlabel('Date')
plt.ylabel('Price in millions')
plt.title('Net Income in Yearly')
# Out:
# Text(0.5, 1.0, 'Net Income in Yearly')

# %%
stock.balancesheet
# Out:
#                                     2020-12-31    2019-12-31    2018-12-31  \
# Intangible Assets                 1.445000e+09  1.979000e+09  2.220000e+09
# Total Liab                        9.707200e+10  7.446700e+10  5.516400e+10
# Total Stockholder Equity          2.225440e+11  2.014420e+11  1.776280e+11
# Other Current Liab                2.725200e+10  2.215900e+10  1.761200e+10
# Total Assets                      3.196160e+11  2.759090e+11  2.327920e+11
# Common Stock                      5.851000e+10  5.055200e+10  4.504900e+10
# Other Current Assets              5.490000e+09  4.412000e+09  4.236000e+09
# Retained Earnings                 1.634010e+11  1.521220e+11  1.348850e+11
# Other Liab                        1.516000e+10  1.447800e+10  1.653200e+10
# Good Will                         2.117500e+10  2.062400e+10  1.788800e+10
# Treasury Stock                    6.330000e+08 -1.232000e+09 -2.306000e+09
# Other Assets                      4.608000e+09  3.063000e+09  3.430000e+09
# Cash                              2.646500e+10  1.849800e+10  1.670100e+10
# Total Current Liabilities         5.683400e+10  4.522100e+10  3.462000e+10
# Deferred Long Term Asset Charges  1.084000e+09  7.210000e+08  7.370000e+08
# Short Long Term Debt              9.990000e+08           NaN           NaN
# Other Stockholder Equity          6.330000e+08 -1.232000e+09 -2.306000e+09
# Property Plant Equipment          9.696000e+10  8.458700e+10  5.971900e+10
# Total Current Assets              1.742960e+11  1.525780e+11  1.356760e+11
# Long Term Investments             2.113200e+10  1.307800e+10  1.385900e+10
# Net Tangible Assets               1.999240e+11  1.788390e+11  1.575200e+11
# Short Term Investments            1.102290e+11  1.011770e+11  9.243900e+10
# Net Receivables                   3.138400e+10  2.749200e+10  2.119300e+10
# Long Term Debt                    1.283200e+10  3.958000e+09  3.950000e+09
# Inventory                         7.280000e+08  9.990000e+08  1.107000e+09
# Accounts Payable                  5.589000e+09  5.561000e+09  4.378000e+09
#
#                                     2017-12-31
# Intangible Assets                 2.692000e+09
# Total Liab                        4.479300e+10
# Total Stockholder Equity          1.525020e+11
# Other Current Liab                1.065100e+10
# Total Assets                      1.972950e+11
# Common Stock                      4.024700e+10
# Other Current Assets              2.983000e+09
# Retained Earnings                 1.132470e+11
# Other Liab                        1.664100e+10
# Good Will                         1.674700e+10
# Treasury Stock                   -9.920000e+08
# Other Assets                      3.352000e+09
# Cash                              1.071500e+10
# Total Current Liabilities         2.418300e+10
# Deferred Long Term Asset Charges  6.800000e+08
# Short Long Term Debt                       NaN
# Other Stockholder Equity         -9.920000e+08
# Property Plant Equipment          4.238300e+10
# Total Current Assets              1.243080e+11
# Long Term Investments             7.813000e+09
# Net Tangible Assets               1.330630e+11
# Short Term Investments            9.115600e+10
# Net Receivables                   1.870500e+10
# Long Term Debt                    3.943000e+09
# Inventory                         7.490000e+08
# Accounts Payable                  3.137000e+09

# %%
BS = stock.balancesheet.iloc[:,::-1] # Reverse Column

# %%
BS
# Out:
#                                     2017-12-31    2018-12-31    2019-12-31  \
# Intangible Assets                 2.692000e+09  2.220000e+09  1.979000e+09
# Total Liab                        4.479300e+10  5.516400e+10  7.446700e+10
# Total Stockholder Equity          1.525020e+11  1.776280e+11  2.014420e+11
# Other Current Liab                1.065100e+10  1.761200e+10  2.215900e+10
# Total Assets                      1.972950e+11  2.327920e+11  2.759090e+11
# Common Stock                      4.024700e+10  4.504900e+10  5.055200e+10
# Other Current Assets              2.983000e+09  4.236000e+09  4.412000e+09
# Retained Earnings                 1.132470e+11  1.348850e+11  1.521220e+11
# Other Liab                        1.664100e+10  1.653200e+10  1.447800e+10
# Good Will                         1.674700e+10  1.788800e+10  2.062400e+10
# Treasury Stock                   -9.920000e+08 -2.306000e+09 -1.232000e+09
# Other Assets                      3.352000e+09  3.430000e+09  3.063000e+09
# Cash                              1.071500e+10  1.670100e+10  1.849800e+10
# Total Current Liabilities         2.418300e+10  3.462000e+10  4.522100e+10
# Deferred Long Term Asset Charges  6.800000e+08  7.370000e+08  7.210000e+08
# Short Long Term Debt                       NaN           NaN           NaN
# Other Stockholder Equity         -9.920000e+08 -2.306000e+09 -1.232000e+09
# Property Plant Equipment          4.238300e+10  5.971900e+10  8.458700e+10
# Total Current Assets              1.243080e+11  1.356760e+11  1.525780e+11
# Long Term Investments             7.813000e+09  1.385900e+10  1.307800e+10
# Net Tangible Assets               1.330630e+11  1.575200e+11  1.788390e+11
# Short Term Investments            9.115600e+10  9.243900e+10  1.011770e+11
# Net Receivables                   1.870500e+10  2.119300e+10  2.749200e+10
# Long Term Debt                    3.943000e+09  3.950000e+09  3.958000e+09
# Inventory                         7.490000e+08  1.107000e+09  9.990000e+08
# Accounts Payable                  3.137000e+09  4.378000e+09  5.561000e+09
#
#                                     2020-12-31
# Intangible Assets                 1.445000e+09
# Total Liab                        9.707200e+10
# Total Stockholder Equity          2.225440e+11
# Other Current Liab                2.725200e+10
# Total Assets                      3.196160e+11
# Common Stock                      5.851000e+10
# Other Current Assets              5.490000e+09
# Retained Earnings                 1.634010e+11
# Other Liab                        1.516000e+10
# Good Will                         2.117500e+10
# Treasury Stock                    6.330000e+08
# Other Assets                      4.608000e+09
# Cash                              2.646500e+10
# Total Current Liabilities         5.683400e+10
# Deferred Long Term Asset Charges  1.084000e+09
# Short Long Term Debt              9.990000e+08
# Other Stockholder Equity          6.330000e+08
# Property Plant Equipment          9.696000e+10
# Total Current Assets              1.742960e+11
# Long Term Investments             2.113200e+10
# Net Tangible Assets               1.999240e+11
# Short Term Investments            1.102290e+11
# Net Receivables                   3.138400e+10
# Long Term Debt                    1.283200e+10
# Inventory                         7.280000e+08
# Accounts Payable                  5.589000e+09

# %%
BS.loc['Retained Earnings']
# Out:
# 2017-12-31    1.132470e+11
# 2018-12-31    1.348850e+11
# 2019-12-31    1.521220e+11
# 2020-12-31    1.634010e+11
# Name: Retained Earnings, dtype: float64

# %%
CR = BS.loc['Total Current Assets'].astype(int) / BS.loc['Total Current Liabilities'].astype(int)
CR
# Out:
# 2017-12-31    1.0
# 2018-12-31    1.0
# 2019-12-31    1.0
# 2020-12-31    1.0
# dtype: float64

# %%
stock.cashflow
# Out:
#                                              2020-12-31    2019-12-31  \
# Investments                               -9.822000e+09 -4.017000e+09
# Change To Liabilities                      1.329000e+09  4.650000e+08
# Total Cashflows From Investing Activities -3.277300e+10 -2.949100e+10
# Net Borrowings                             9.661000e+09 -2.680000e+08
# Total Cash From Financing Activities      -2.440800e+10 -2.320900e+10
# Change To Operating Activities             5.813000e+09  7.822000e+09
# Net Income                                 4.026900e+10  3.434300e+10
# Change In Cash                             7.967000e+09  1.797000e+09
# Repurchase Of Stock                       -3.114900e+10 -1.839600e+10
# Effect Of Exchange Rate                    2.400000e+07 -2.300000e+07
# Total Cash From Operating Activities       6.512400e+10  5.452000e+10
# Depreciation                               1.367900e+10  1.165100e+10
# Other Cashflows From Investing Activities  6.800000e+07  5.890000e+08
# Change To Account Receivables             -6.524000e+09 -4.340000e+09
# Other Cashflows From Financing Activities -2.920000e+09 -4.545000e+09
# Change To Netincome                        9.349000e+09  7.707000e+09
# Capital Expenditures                      -2.228100e+10 -2.354800e+10
#
#                                              2018-12-31    2017-12-31
# Investments                               -1.972000e+09 -1.944800e+10
# Change To Liabilities                      1.438000e+09  1.121000e+09
# Total Cashflows From Investing Activities -2.850400e+10 -3.140100e+10
# Net Borrowings                            -6.100000e+07 -8.600000e+07
# Total Cash From Financing Activities      -1.317900e+10 -8.298000e+09
# Change To Operating Activities             7.890000e+09  3.682000e+09
# Net Income                                 3.073600e+10  1.266200e+10
# Change In Cash                             5.986000e+09 -2.203000e+09
# Repurchase Of Stock                       -9.075000e+09 -4.846000e+09
# Effect Of Exchange Rate                   -3.020000e+08  4.050000e+08
# Total Cash From Operating Activities       4.797100e+10  3.709100e+10
# Depreciation                               9.029000e+09  6.899000e+09
# Other Cashflows From Investing Activities  9.800000e+07  1.419000e+09
# Change To Account Receivables             -2.169000e+09 -3.768000e+09
# Other Cashflows From Financing Activities -4.043000e+09 -3.366000e+09
# Change To Netincome                        3.298000e+09  8.284000e+09
# Capital Expenditures                      -2.513900e+10 -1.318400e+10

# %%
CF = stock.cashflow.loc[::,::-1] # Reverse Column

# %%
CF
# Out:
#                                              2017-12-31    2018-12-31  \
# Investments                               -1.944800e+10 -1.972000e+09
# Change To Liabilities                      1.121000e+09  1.438000e+09
# Total Cashflows From Investing Activities -3.140100e+10 -2.850400e+10
# Net Borrowings                            -8.600000e+07 -6.100000e+07
# Total Cash From Financing Activities      -8.298000e+09 -1.317900e+10
# Change To Operating Activities             3.682000e+09  7.890000e+09
# Net Income                                 1.266200e+10  3.073600e+10
# Change In Cash                            -2.203000e+09  5.986000e+09
# Repurchase Of Stock                       -4.846000e+09 -9.075000e+09
# Effect Of Exchange Rate                    4.050000e+08 -3.020000e+08
# Total Cash From Operating Activities       3.709100e+10  4.797100e+10
# Depreciation                               6.899000e+09  9.029000e+09
# Other Cashflows From Investing Activities  1.419000e+09  9.800000e+07
# Change To Account Receivables             -3.768000e+09 -2.169000e+09
# Other Cashflows From Financing Activities -3.366000e+09 -4.043000e+09
# Change To Netincome                        8.284000e+09  3.298000e+09
# Capital Expenditures                      -1.318400e+10 -2.513900e+10
#
#                                              2019-12-31    2020-12-31
# Investments                               -4.017000e+09 -9.822000e+09
# Change To Liabilities                      4.650000e+08  1.329000e+09
# Total Cashflows From Investing Activities -2.949100e+10 -3.277300e+10
# Net Borrowings                            -2.680000e+08  9.661000e+09
# Total Cash From Financing Activities      -2.320900e+10 -2.440800e+10
# Change To Operating Activities             7.822000e+09  5.813000e+09
# Net Income                                 3.434300e+10  4.026900e+10
# Change In Cash                             1.797000e+09  7.967000e+09
# Repurchase Of Stock                       -1.839600e+10 -3.114900e+10
# Effect Of Exchange Rate                   -2.300000e+07  2.400000e+07
# Total Cash From Operating Activities       5.452000e+10  6.512400e+10
# Depreciation                               1.165100e+10  1.367900e+10
# Other Cashflows From Investing Activities  5.890000e+08  6.800000e+07
# Change To Account Receivables             -4.340000e+09 -6.524000e+09
# Other Cashflows From Financing Activities -4.545000e+09 -2.920000e+09
# Change To Netincome                        7.707000e+09  9.349000e+09
# Capital Expenditures                      -2.354800e+10 -2.228100e+10

# %%
print('Short term solvency ratios')
print('-'*40)
print('Current Ratio')
CR = BS.loc['Total Current Assets'].astype(int) / BS.loc['Total Current Liabilities'].astype(int) # Total Current Assets/Total Current Liabilities
print(CR,"\n")
print('Quick Ratio')
QR = (BS.loc['Total Current Assets'].astype(int) - BS.loc['Inventory'].astype(int)) / BS.loc['Total Current Liabilities'].astype(int) # (Total Current Assets-Inventory)/Total Current Liabilities
print(QR,"\n")
# Out:
# Short term solvency ratios
# ----------------------------------------
# Current Ratio
#
# 2017-12-31    1.0
# 2018-12-31    1.0
# 2019-12-31    1.0
# 2020-12-31    1.0
# dtype: float64
#
# Quick Ratio
#
# 2017-12-31   -0.651220
# 2018-12-31   -0.484513
# 2019-12-31   -0.534804
# 2020-12-31   -0.660999
# dtype: float64
